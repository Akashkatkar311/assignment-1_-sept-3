# %% [markdown]
# Problem :
#             Analysis of covid data from CDC (center of disease control) to see corellation between vaccination, comorbidities, age and mask mandates with covid deaths to conclude if vaccinations and mask mandates
#
# Solution:
#
# Data Points:
#
# Conclusion:
#
# References for datasets used

# %%
#importing Required library 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#importing plotly Library

from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
#importing the datase

df_vac=pd.read_csv(r"C:\Users\akash\covid\COVID-19_Vaccination_Trends_in_the_United_States_National_and_Jurisdictional.csv")
df_vac.head(5)
# Out:
#          Date  MMWR_week Location Administered_Daily Administered_Cumulative  \
# 0  10/08/2021         40       MT                  0               1,115,986
# 1  10/08/2021         40       WA                  0               9,798,601
# 2  10/08/2021         40       SC                  0               5,394,101
# 3  10/08/2021         40       AR                  0               3,085,323
# 4  10/08/2021         40       NC                  1              11,640,273
#
#   Administered_7_Day_Rolling_Average Admin_Dose_1_Daily  \
# 0                              1,452                  0
# 1                             10,329                  0
# 2                              7,444                  0
# 3                              3,228                  0
# 4                             16,445                  1
#
#   Admin_Dose_1_Cumulative Admin_Dose_1_Day_Rolling_Average date_type  \
# 0                 594,532                              306     Admin
# ...

# %%
df_vac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36001 entries, 0 to 36000
# Data columns (total 15 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       36001 non-null  object
#  1   MMWR_week                                  36001 non-null  int64
#  2   Location                                   36000 non-null  object
#  3   Administered_Daily                         36001 non-null  object
#  4   Administered_Cumulative                    36001 non-null  object
#  5   Administered_7_Day_Rolling_Average         36001 non-null  object
#  6   Admin_Dose_1_Daily                         36001 non-null  object
#  7   Admin_Dose_1_Cumulative                    36001 non-null  object
#  8   Admin_Dose_1_Day_Rolling_Average           36001 non-null  object
#  9   date_type                                  36001 non-null  object
# ...
